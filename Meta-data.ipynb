# %%
import pandas as pd
import os
import numpy as np
os.chdir(r'C:\Users\tselb\OneDrive - University of Cambridge\Documents\Mini 2\FRAP')
os.chdir(r'Data\25.02\OneDrive_2_25-02-2022\Bilayer3_post bleach7_1')
meta_data_filename= 'Bilayer3_post bleach7_1_MMStack_Default_metadata.txt'
md = pd.read_json(meta_data_filename)

# %%
md
# Out:
#                                      Summary  \
# Prefix               Bilayer3_post bleach7_1
# UserName                          Biscutella
# ProfileName                     Default User
# MicroManagerVersion                    2.0.0
# ComputerName                    biscutella21
# ...                                      ...
# Camera-ChipName                          NaN
# Nosepiece-State                          NaN
# Core-Shutter                             NaN
# ScopeDataKeys                            NaN
# FileName                                 NaN
#
#                                                         FrameKey-0-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                         FrameKey-1-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                         FrameKey-2-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                         FrameKey-3-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                         FrameKey-4-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                         FrameKey-5-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                         FrameKey-6-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                         FrameKey-7-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                         FrameKey-8-0-0  ...  \
# Prefix                                                             NaN  ...
# UserName                                                           NaN  ...
# ProfileName                                                        NaN  ...
# MicroManagerVersion                                                NaN  ...
# ComputerName                                                       NaN  ...
# ...                                                                ...  ...
# Camera-ChipName                                       Evolve-512-Delta  ...
# Nosepiece-State                                                      2  ...
# Core-Shutter                                             Shutter-1_488  ...
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...  ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif  ...
#
#                                                      FrameKey-2990-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                      FrameKey-2991-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                      FrameKey-2992-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                      FrameKey-2993-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                      FrameKey-2994-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                      FrameKey-2995-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                      FrameKey-2996-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                      FrameKey-2997-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                      FrameKey-2998-0-0  \
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
#                                                      FrameKey-2999-0-0
# Prefix                                                             NaN
# UserName                                                           NaN
# ProfileName                                                        NaN
# MicroManagerVersion                                                NaN
# ComputerName                                                       NaN
# ...                                                                ...
# Camera-ChipName                                       Evolve-512-Delta
# Nosepiece-State                                                      2
# Core-Shutter                                             Shutter-1_488
# ScopeDataKeys        [COM6-StopBits, iBeamSmartCW-405-Description, ...
# FileName               Bilayer3_post bleach7_1_MMStack_Default.ome.tif
#
# [222 rows x 3001 columns]

# %%
time = md.loc['ElapsedTime-ms'][1:]- md.loc['ElapsedTime-ms'][1]

# %%
time
# Out:
# FrameKey-0-0-0            0.0
# FrameKey-1-0-0          32.91
# FrameKey-2-0-0          65.82
# FrameKey-3-0-0          98.73
# FrameKey-4-0-0         131.65
#                        ...
# FrameKey-2995-0-0    99188.24
# FrameKey-2996-0-0    99221.31
# FrameKey-2997-0-0    99254.19
# FrameKey-2998-0-0     99288.1
# FrameKey-2999-0-0    99321.11
# Name: ElapsedTime-ms, Length: 3000, dtype: object
