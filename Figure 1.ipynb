# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from skimage import io
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import matplotlib.font_manager as fm
fontprops = fm.FontProperties(size=11)

# %%
os.chdir(r'C:\Users\tselb\OneDrive - University of Cambridge\Documents\Mini 2\Figure 1') #import images
popc_bad_1 = io.imread('well1_561nm_OD2_1_MMStack_Pos0.ome (1).tif')
popc_good_1 = io.imread('well1_slide3_561nm_OD1p6_POPC(1)-TMR_0p5mgmL_Epi_3_MMStack_Pos0.ome.tif')
popc_bad_1 = bad_1.astype(float) #Convert the entries in each array to floats
popc_good_1 = good_1.astype(float) #Convert the entries in each array to floats

ni= io.imread('well2_slide2_561nm_OD1p6_Ni(2)-TMR_0p5mgmL_Epi_1_MMStack_Pos0.ome.tif')
ni=ni.astype(float)
snap3=io.imread('well3_slide2_561nm_OD1p6_SNAP(3)-TMR_0p5mgmL_Epi_3_MMStack_Pos0.ome.tif')
snap3=snap3.astype(float)
snap4=io.imread('well4_slide2_561nm_OD1p6_SNAP(4)-TMR_0p5mgmL_Epi_1_MMStack_Pos0.ome.tif')
snap4=snap4.astype(float)

# %%
fig,ax = plt.subplots(1,5)
cmap = plt.cm.gray
exp_list = [popc_bad_1, popc_good_1,ni,snap3,snap4]
scale_bar_size = 10 #in um
pixel_width =107/1000 #in um
title_list = ['POPC before \noptimisation','POPC after \noptimisation', 'Ni-NTA (2%)','SNAP (2%)', 'SNAP (10%)']
scalebar = AnchoredSizeBar(ax[0].transData,
                           scale_bar_size/pixel_width, str(10) +' μm', 'lower left', 
                           pad=0.1,
                           color='white',
                           frameon=False,
                           size_vertical=5,
                           fontproperties=fontprops)






for i in range(5):
    ax[i].imshow(exp_list[i][0],cmap=cmap)
    ax[i].set_xticks([])
    ax[i].set_yticks([])
    ax[i].set_title(title_list[i],fontproperties=fontprops)

ax[0].add_artist(scalebar)
fig.set_size_inches(7, 2)

    
plt.tight_layout()
plt.savefig('Figure 1.png',dpi=600)
